# %%
pip install ipywidgets
# Out:
# Requirement already satisfied: ipywidgets in c:\users\st735\.conda\envs\synlinker\lib\site-packages (8.1.8)
# Requirement already satisfied: comm>=0.1.3 in c:\users\st735\.conda\envs\synlinker\lib\site-packages (from ipywidgets) (0.2.3)
# Requirement already satisfied: ipython>=6.1.0 in c:\users\st735\.conda\envs\synlinker\lib\site-packages (from ipywidgets) (8.37.0)
# Requirement already satisfied: traitlets>=4.3.1 in c:\users\st735\.conda\envs\synlinker\lib\site-packages (from ipywidgets) (5.14.3)
# Requirement already satisfied: widgetsnbextension~=4.0.14 in c:\users\st735\.conda\envs\synlinker\lib\site-packages (from ipywidgets) (4.0.15)
# Requirement already satisfied: jupyterlab_widgets~=3.0.15 in c:\users\st735\.conda\envs\synlinker\lib\site-packages (from ipywidgets) (3.0.16)
# Requirement already satisfied: colorama in c:\users\st735\.conda\envs\synlinker\lib\site-packages (from ipython>=6.1.0->ipywidgets) (0.4.6)
# Requirement already satisfied: decorator in c:\users\st735\.conda\envs\synlinker\lib\site-packages (from ipython>=6.1.0->ipywidgets) (5.2.1)
# Requirement already satisfied: exceptiongroup in c:\users\st735\.conda\envs\synlinker\lib\site-packages (from ipython>=6.1.0->ipywidgets) (1.3.1)
# Requirement already satisfied: jedi>=0.16 in c:\users\st735\.conda\envs\synlinker\lib\site-packages (from ipython>=6.1.0->ipywidgets) (0.19.2)
# Requirement already satisfied: matplotlib-inline in c:\users\st735\.conda\envs\synlinker\lib\site-packages (from ipython>=6.1.0->ipywidgets) (0.2.1)
# Requirement already satisfied: prompt_toolkit<3.1.0,>=3.0.41 in c:\users\st735\.conda\envs\synlinker\lib\site-packages (from ipython>=6.1.0->ipywidgets) (3.0.52)
# Requirement already satisfied: pygments>=2.4.0 in c:\users\st735\.conda\envs\synlinker\lib\site-packages (from ipython>=6.1.0->ipywidgets) (2.19.2)
# Requirement already satisfied: stack_data in c:\users\st735\.conda\envs\synlinker\lib\site-packages (from ipython>=6.1.0->ipywidgets) (0.6.3)
# Requirement already satisfied: typing_extensions>=4.6 in c:\users\st735\.conda\envs\synlinker\lib\site-packages (from ipython>=6.1.0->ipywidgets) (4.14.0)
# Requirement already satisfied: wcwidth in c:\users\st735\.conda\envs\synlinker\lib\site-packages (from prompt_toolkit<3.1.0,>=3.0.41->ipython>=6.1.0->ipywidgets) (0.2.14)
# Requirement already satisfied: parso<0.9.0,>=0.8.4 in c:\users\st735\.conda\envs\synlinker\lib\site-packages (from jedi>=0.16->ipython>=6.1.0->ipywidgets) (0.8.5)
# Requirement already satisfied: executing>=1.2.0 in c:\users\st735\.conda\envs\synlinker\lib\site-packages (from stack_data->ipython>=6.1.0->ipywidgets) (2.2.1)
# Requirement already satisfied: asttokens>=2.1.0 in c:\users\st735\.conda\envs\synlinker\lib\site-packages (from stack_data->ipython>=6.1.0->ipywidgets) (3.0.1)
# Requirement already satisfied: pure_eval in c:\users\st735\.conda\envs\synlinker\lib\site-packages (from stack_data->ipython>=6.1.0->ipywidgets) (0.2.3)
# Note: you may need to restart the kernel to use updated packages.

# %%
pip install Bio
# Out:
# Collecting Bio
#   Downloading bio-1.8.1-py3-none-any.whl.metadata (5.7 kB)
# Collecting biopython>=1.80 (from Bio)
#   Downloading biopython-1.86-cp310-cp310-win_amd64.whl.metadata (13 kB)
# Collecting gprofiler-official (from Bio)
#   Using cached gprofiler_official-1.0.0-py3-none-any.whl.metadata (11 kB)
# Collecting mygene (from Bio)
#   Using cached mygene-3.2.2-py2.py3-none-any.whl.metadata (10 kB)
# Requirement already satisfied: pandas in c:\users\st735\.conda\envs\synlinker\lib\site-packages (from Bio) (2.3.0)
# Collecting pooch (from Bio)
#   Using cached pooch-1.8.2-py3-none-any.whl.metadata (10 kB)
# Requirement already satisfied: requests in c:\users\st735\.conda\envs\synlinker\lib\site-packages (from Bio) (2.32.4)
# Requirement already satisfied: tqdm in c:\users\st735\.conda\envs\synlinker\lib\site-packages (from Bio) (4.67.1)
# Requirement already satisfied: numpy in c:\users\st735\.conda\envs\synlinker\lib\site-packages (from biopython>=1.80->Bio) (2.1.3)
# Collecting biothings-client>=0.2.6 (from mygene->Bio)
#   Downloading biothings_client-0.4.1-py3-none-any.whl.metadata (10 kB)
# Collecting httpx>=0.22.0 (from biothings-client>=0.2.6->mygene->Bio)
#   Using cached httpx-0.28.1-py3-none-any.whl.metadata (7.1 kB)
# Collecting anyio (from httpx>=0.22.0->biothings-client>=0.2.6->mygene->Bio)
#   Using cached anyio-4.12.1-py3-none-any.whl.metadata (4.3 kB)
# Requirement already satisfied: certifi in c:\users\st735\.conda\envs\synlinker\lib\site-packages (from httpx>=0.22.0->biothings-client>=0.2.6->mygene->Bio) (2025.6.15)
# Collecting httpcore==1.* (from httpx>=0.22.0->biothings-client>=0.2.6->mygene->Bio)
#   Using cached httpcore-1.0.9-py3-none-any.whl.metadata (21 kB)
# Requirement already satisfied: idna in c:\users\st735\.conda\envs\synlinker\lib\site-packages (from httpx>=0.22.0->biothings-client>=0.2.6->mygene->Bio) (3.10)
# Collecting h11>=0.16 (from httpcore==1.*->httpx>=0.22.0->biothings-client>=0.2.6->mygene->Bio)
#   Using cached h11-0.16.0-py3-none-any.whl.metadata (8.3 kB)
# Requirement already satisfied: exceptiongroup>=1.0.2 in c:\users\st735\.conda\envs\synlinker\lib\site-packages (from anyio->httpx>=0.22.0->biothings-client>=0.2.6->mygene->Bio) (1.3.1)
# Requirement already satisfied: typing_extensions>=4.5 in c:\users\st735\.conda\envs\synlinker\lib\site-packages (from anyio->httpx>=0.22.0->biothings-client>=0.2.6->mygene->Bio) (4.14.0)
# Requirement already satisfied: python-dateutil>=2.8.2 in c:\users\st735\.conda\envs\synlinker\lib\site-packages (from pandas->Bio) (2.9.0.post0)
# Requirement already satisfied: pytz>=2020.1 in c:\users\st735\.conda\envs\synlinker\lib\site-packages (from pandas->Bio) (2025.2)
# Requirement already satisfied: tzdata>=2022.7 in c:\users\st735\.conda\envs\synlinker\lib\site-packages (from pandas->Bio) (2025.2)
# Requirement already satisfied: six>=1.5 in c:\users\st735\.conda\envs\synlinker\lib\site-packages (from python-dateutil>=2.8.2->pandas->Bio) (1.17.0)
# Requirement already satisfied: platformdirs>=2.5.0 in c:\users\st735\.conda\envs\synlinker\lib\site-packages (from pooch->Bio) (4.3.8)
# Requirement already satisfied: packaging>=20.0 in c:\users\st735\.conda\envs\synlinker\lib\site-packages (from pooch->Bio) (25.0)
# Requirement already satisfied: charset_normalizer<4,>=2 in c:\users\st735\.conda\envs\synlinker\lib\site-packages (from requests->Bio) (3.4.2)
# Requirement already satisfied: urllib3<3,>=1.21.1 in c:\users\st735\.conda\envs\synlinker\lib\site-packages (from requests->Bio) (2.5.0)
# Requirement already satisfied: colorama in c:\users\st735\.conda\envs\synlinker\lib\site-packages (from tqdm->Bio) (0.4.6)
# Downloading bio-1.8.1-py3-none-any.whl (321 kB)
# Downloading biopython-1.86-cp310-cp310-win_amd64.whl (2.7 MB)
#    ---------------------------------------- 0.0/2.7 MB ? eta -:--:--
#    ------------------------------ --------- 2.1/2.7 MB 11.8 MB/s eta 0:00:01
#    ------------------------------ --------- 2.1/2.7 MB 11.8 MB/s eta 0:00:01
#    ---------------------------------------- 2.7/2.7 MB 4.3 MB/s eta 0:00:00
# Using cached gprofiler_official-1.0.0-py3-none-any.whl (9.3 kB)
# Using cached mygene-3.2.2-py2.py3-none-any.whl (5.4 kB)
# Downloading biothings_client-0.4.1-py3-none-any.whl (46 kB)
# Downloading httpx-0.28.1-py3-none-any.whl (73 kB)
# Downloading httpcore-1.0.9-py3-none-any.whl (78 kB)
# Downloading h11-0.16.0-py3-none-any.whl (37 kB)
# Downloading anyio-4.12.1-py3-none-any.whl (113 kB)
# Using cached pooch-1.8.2-py3-none-any.whl (64 kB)
# Installing collected packages: h11, biopython, pooch, httpcore, gprofiler-official, anyio, httpx, biothings-client, mygene, Bio
#
#    ---- -----------------------------------  1/10 [biopython]
#    ---- -----------------------------------  1/10 [biopython]
#    ---- -----------------------------------  1/10 [biopython]
#    ---- -----------------------------------  1/10 [biopython]
#    ---- -----------------------------------  1/10 [biopython]
#    ---- -----------------------------------  1/10 [biopython]
#    -------------------- -------------------  5/10 [anyio]
#    ---------------------------- -----------  7/10 [biothings-client]
#    ---------------------------------------- 10/10 [Bio]
#
# Successfully installed Bio-1.8.1 anyio-4.12.1 biopython-1.86 biothings-client-0.4.1 gprofiler-official-1.0.0 h11-0.16.0 httpcore-1.0.9 httpx-0.28.1 mygene-3.2.2 pooch-1.8.2
# Note: you may need to restart the kernel to use updated packages.

# %%
# ==============================================================================
# 0. PEFT IMPORTS AND INITIAL SETUP (NEW)
# ==============================================================================
# Ensure you have the peft library installed: pip install peft
from peft import LoraConfig, get_peft_model, TaskType

print("\n" + "="*80)
print("... 0. PEFT LIBRARY INITIALIZED ...")
print("    Ready for Parameter-Efficient Fine-Tuning with LoRA!")
# ==============================================================================
# 1. IMPORTS AND INITIAL SETUP
# ==============================================================================
import os
import sys
import time
import json
import random
import pickle
from pathlib import Path
from datetime import datetime

# Standard data science libraries
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
# In the IMPORTS AND INITIAL SETUP section
from tqdm import tqdm
import warnings

# Machine learning libraries
from sklearn.model_selection import KFold, GroupKFold
from sklearn.metrics import mean_squared_error
from scipy.stats import pearsonr, spearmanr

# PyTorch and Transformers
import torch
import torch.nn as nn
import torch.nn.functional as F
from torch.utils.data import Dataset, DataLoader
from torch.optim import AdamW
from transformers import AutoModel, AutoTokenizer

# Advanced CV imports (optional, kept for context)
from Bio.Align import PairwiseAligner
from scipy.cluster.hierarchy import linkage, fcluster
from multiprocessing import Pool, cpu_count
from typing import List, Tuple

# Set style for plots
plt.style.use('seaborn-v0_8')
sns.set_palette("husl")
warnings.filterwarnings('ignore', category=UserWarning)

# --- MODIFIED: Title reflects the use of ESM-2 ---
print("🧬 BALM Adaptation for ESM-2 with LoRA Fine-Tuning")
print("⚡ Fast Training with 5-Fold Cross-Validation")
print("="*80)

def setup_reproducibility(seed=42):
    """Setup complete reproducibility."""
    print(f"🔒 Setting up reproducibility with seed {seed}")
    random.seed(seed)
    np.random.seed(seed)
    torch.manual_seed(seed)
    if torch.cuda.is_available():
        torch.cuda.manual_seed(seed)
        torch.cuda.manual_seed_all(seed)
        torch.backends.cudnn.deterministic = True
        torch.backends.cudnn.benchmark = False
    os.environ['PYTHONHASHSEED'] = str(seed)
    print(f"✅ Reproducibility setup complete")

setup_reproducibility(42)

# ==============================================================================
# 2. ESM-2 EMBEDDING EXTRACTOR (Modified for LoRA)
# ==============================================================================

class ProteinEmbeddingExtractor:
    """
    A class to prepare the ESM-2 model, optionally with LoRA adapters.
    This class handles model loading and tokenization.
    """
    def __init__(
        self,
        model_name="facebook/esm2_t33_650M_UR50D",
        device="auto",
        lora_rank=8,
        lora_alpha=16,
        lora_dropout=0.1,
        use_lora=True
    ):
        self.model_name = model_name
        self.use_lora = use_lora

        if device == "auto":
            self.device = torch.device("cuda" if torch.cuda.is_available() else "cpu")
        else:
            self.device = torch.device(device)

        print(f"🔧 Initializing ProteinEmbeddingExtractor on {self.device}")

        self.dtype = torch.float16 if self.device.type == 'cuda' else torch.float32
        print(f"📥 Loading ESM-2 model: {model_name} with dtype: {self.dtype}")

        self.model = AutoModel.from_pretrained(
            model_name,
            torch_dtype=self.dtype
        )
        self.tokenizer = AutoTokenizer.from_pretrained(model_name)

        if self.use_lora:
            print(f"✨ Applying LoRA with rank={lora_rank}, alpha={lora_alpha}, dropout={lora_dropout}")
            lora_config = LoraConfig(
                r=lora_rank,
                lora_alpha=lora_alpha,
                lora_dropout=lora_dropout,
                bias="none",
                task_type=TaskType.FEATURE_EXTRACTION,
                target_modules=["key", "query", "value"] # Common target modules for attention
            )
            self.model = get_peft_model(self.model, lora_config)
            print("   ✅ LoRA model loaded and configured. Trainable parameters:")
            self.model.print_trainable_parameters()
        else:
            print("   ⚠️ LoRA is disabled. All base model weights are frozen.")
            for param in self.model.parameters():
                param.requires_grad = False

        self.model.to(self.device)
        self.embedding_size = self.model.config.hidden_size
        print(f"   ✅ Model loaded. Embedding size from config: {self.embedding_size}")

    def get_model_and_tokenizer(self):
        """Returns the prepared model (PeftModel or base) and tokenizer."""
        return self.model, self.tokenizer

# ==============================================================================
# 3. LOAD YOUR DATASET (MODIFIED)
# ==============================================================================
protein1_col = 'Target'
protein2_col = 'proteina'
target_col = 'Y'
pdb_col_raw = 'PDB'
subgroup_col = 'Subgroup'
source_dataset_col = 'Source Data Set' # NEW
ligand_col = 'Ligand Name'   # NEW
receptor_col = 'Receptor Name' # NEW

try:
    df_raw = pd.read_csv(r'C:\Users\hs494\PPIBALM\BALM-PPI\scripts\notebooks\PPB_Affinity_Sequences_Final (version 1).csv')

    cols_to_keep = [protein1_col, protein2_col, target_col, pdb_col_raw, 
                    subgroup_col, source_dataset_col, ligand_col, receptor_col]
    # Include Source Data Set in the selection
    df = df_raw[cols_to_keep].copy()
    df.rename(columns={
        protein1_col: 'Target',
        protein2_col: 'proteina',
        target_col: 'Y',
        pdb_col_raw: 'PDB',
        subgroup_col: 'Subgroup',
        source_dataset_col: 'SourceDataSet',
        ligand_col: 'LigandName',    # Internal mapping
        receptor_col: 'ReceptorName' # Internal mapping
    }, inplace=True)

    # Clean data (ensure we have names even if strings)
    df.dropna(subset=['Target', 'proteina', 'Y'], inplace=True)
    for c in ['Target', 'proteina', 'PDB', 'Subgroup', 'SourceDataSet', 'LigandName', 'ReceptorName']:
        df[c] = df[c].astype(str)
    
    df['Y'] = pd.to_numeric(df['Y'], errors='coerce')
    df.dropna(subset=['Y'], inplace=True)

    print(f"✅ Data loaded. Final dataset size: {len(df)} samples.")
except Exception as e:
    print(f"❌ ERROR LOADING DATA: {e}")

# ==============================================================================
# 4. EXPERIMENT CONFIGURATION
# ==============================================================================
print("\n" + "="*80)
print("... 4. CONFIGURING THE EXPERIMENT ...")

CV_STRATEGY = 'GroupKFold'
N_SPLITS = 5 # This will result in 80/20 train/test splits for GroupKFold
EPOCHS = 30
PATIENCE = 15
BATCH_SIZE = 1 # Keep as 1 for sequence models unless you have padding issues or specific needs
LEARNING_RATE = 1e-4
PROJECTED_SIZE = 256
DROPOUT = 0.1

LORA_RANK = 8
LORA_ALPHA = 16
LORA_DROPOUT = 0.1
USE_LORA_FOR_TRAINING = True

# Output directory for results
RESULTS_DIR = "cv_results_lora"
os.makedirs(RESULTS_DIR, exist_ok=True)
print(f"Results will be saved in: {RESULTS_DIR}")

print(f"✅ Configuration set. Using CV Strategy: {CV_STRATEGY}")
print(f"   Epochs: {EPOCHS}, Patience: {PATIENCE}")
if USE_LORA_FOR_TRAINING:
    print(f"   LoRA Enabled: Rank={LORA_RANK}, Alpha={LORA_ALPHA}, Dropout={LORA_DROPOUT}")
else:
    print(f"   LoRA Disabled: Only projection head will be trained.")

# ==============================================================================
# 5. ADAPTED MODEL AND DATASET
# ==============================================================================
print("\n" + "="*80)
print("... 5. DEFINING ADAPTED MODEL AND DATASET ...")

class BALMProjectionHead(nn.Module):
    def __init__(self, embedding_size, projected_size, projected_dropout):
        super().__init__()
        self.protein_projection = nn.Linear(embedding_size, projected_size)
        self.proteina_projection = nn.Linear(embedding_size, projected_size)
        self.dropout = nn.Dropout(projected_dropout)
        self.loss_fn = nn.MSELoss()
        print(f"✅ BALMProjectionHead initialized with embedding_size: {embedding_size}")

    def forward(self, protein_embedding, proteina_embedding, labels=None):
        protein_embedding = self.dropout(protein_embedding)
        proteina_embedding = self.dropout(proteina_embedding)
        protein_projected = self.protein_projection(protein_embedding)
        proteina_projected = self.proteina_projection(proteina_embedding)
        protein_projected = F.normalize(protein_projected, p=2, dim=1)
        proteina_projected = F.normalize(proteina_projected, p=2, dim=1)
        cosine_similarity = F.cosine_similarity(protein_projected, proteina_projected)
        cosine_similarity = torch.clamp(cosine_similarity, -0.9999, 0.9999) # Clamp to avoid NaNs
        output = {"cosine_similarity": cosine_similarity}
        if labels is not None:
            loss = self.loss_fn(cosine_similarity, labels)
            output["loss"] = loss
        return output

class BALMForLoRAFinetuning(nn.Module):
    def __init__(self, esm_model, esm_tokenizer, projected_size, projected_dropout, pkd_bounds):
        super().__init__()
        self.esm_model = esm_model
        self.esm_tokenizer = esm_tokenizer
        self.embedding_size = self.esm_model.config.hidden_size
        self.projection_head = BALMProjectionHead(self.embedding_size, projected_size, projected_dropout)
        self.pkd_lower, self.pkd_upper = pkd_bounds
        self.pkd_range = self.pkd_upper - self.pkd_lower

        # Identify the CLS token (typically <s> for ESM-2)
        self.cls_token = self.esm_tokenizer.cls_token
        print(f"✅ BALM model initialized using CLS token: {self.cls_token}")

    def _get_esm_embeddings(self, sequences: List[str]):
        """
        Modified to use: Seq1 + CLS + CLS + Seq2
        and perform Mean Pooling across the whole sequence.
        """
        # 1. Replace '|' with '<s><s>'
        processed_seqs = [s.replace('|', f"{self.cls_token}{self.cls_token}") for s in sequences]

        # 2. Tokenize (handles padding and truncation)
        inputs = self.esm_tokenizer(processed_seqs, return_tensors="pt", padding=True, truncation=True, max_length=1024)
        inputs = {k: v.to(self.esm_model.device) for k, v in inputs.items()}

        # 3. Get Hidden States
        outputs = self.esm_model(**inputs)
        hidden_states = outputs.last_hidden_state # [batch, seq_len, hidden_dim]
        attention_mask = inputs['attention_mask']

        # 4. Mean pooling over the whole sequence (ignoring padding tokens)
        mask_expanded = attention_mask.unsqueeze(-1).expand(hidden_states.size()).float()
        sum_embeddings = torch.sum(hidden_states * mask_expanded, 1)
        sum_mask = torch.clamp(mask_expanded.sum(1), min=1e-9)

        return sum_embeddings / sum_mask

    def forward(self, batch_input):
        protein_emb = self._get_esm_embeddings(batch_input["protein_sequence"])
        proteina_emb = self._get_esm_embeddings(batch_input["proteina_sequence"])

        labels = batch_input.get("labels")
        if labels is not None:
            labels = labels.to(self.esm_model.device)

        proj_output = self.projection_head(protein_emb, proteina_emb, labels)

        return {
            "cosine_similarity": proj_output["cosine_similarity"],
            "original_pkds": batch_input["original_pkds"],
            "pdb_groups": batch_input["pdb_groups"],
            "subgroups": batch_input["subgroups"],
            "source_dataset": batch_input["source_dataset"],
            "ligand_name": batch_input["ligand_name"],   # NEW
            "receptor_name": batch_input["receptor_name"], # NEW
            "loss": proj_output.get("loss")
        }

# Update the Dataset and Collate function to include source_dataset
class ProteinPairSequenceDataset(Dataset):
    def __init__(self, dataframe, pkd_bounds):
        self.data = dataframe.reset_index(drop=True)
        self.pkd_lower, self.pkd_upper = pkd_bounds
        self.pkd_range = self.pkd_upper - self.pkd_lower

    def __len__(self):
        return len(self.data)

    def __getitem__(self, idx):
        row = self.data.iloc[idx]
        original_pkd = float(row['Y'])
        scaled_label = ((original_pkd - self.pkd_lower) / self.pkd_range) * 2 - 1
        return {
            "protein_sequence": row["Target"],
            "proteina_sequence": row["proteina"],
            "labels": torch.tensor(scaled_label, dtype=torch.float32),
            "original_pkds": torch.tensor(original_pkd, dtype=torch.float32),
            "pdb_groups": row["PDB"],
            "subgroups": row["Subgroup"],
            "source_dataset": row["SourceDataSet"],
            "ligand_name": row["LigandName"],   # NEW
            "receptor_name": row["ReceptorName"] # NEW
        }

def collate_fn_sequences(batch):
    return {
        "protein_sequence": [item['protein_sequence'] for item in batch],
        "proteina_sequence": [item['proteina_sequence'] for item in batch],
        "labels": torch.stack([item['labels'] for item in batch]),
        "original_pkds": torch.stack([item['original_pkds'] for item in batch]),
        "pdb_groups": [item['pdb_groups'] for item in batch],
        "subgroups": [item['subgroups'] for item in batch],
        "source_dataset": [item['source_dataset'] for item in batch],
        "ligand_name": [item['ligand_name'] for item in batch],     # NEW
        "receptor_name": [item['receptor_name'] for item in batch] # NEW
    }

# ==============================================================================
# 6. METRICS AND EVALUATION FUNCTIONS
# ==============================================================================
print("\n" + "="*80)
print("... 6. DEFINING METRICS AND EVALUATION ...")

def concordance_index(y_true, y_pred):
    """Calculates the Concordance Index (C-index) for regression."""
    try:
        y_true, y_pred = np.array(y_true), np.array(y_pred)
        n = len(y_true)
        if n < 2: return 1.0
        concordant, discordant, tied_pred = 0, 0, 0
        for i in range(n):
            for j in range(i + 1, n):
                if y_true[i] == y_true[j]: continue
                if y_pred[i] == y_pred[j]:
                    tied_pred += 1
                    continue
                if (y_pred[i] > y_pred[j] and y_true[i] > y_true[j]) or \
                   (y_pred[i] < y_pred[j] and y_true[i] < y_true[j]):
                    concordant += 1
                else:
                    discordant += 1
        total_pairs = concordant + discordant + tied_pred
        return 1.0 if total_pairs == 0 else (concordant + 0.5 * tied_pred) / total_pairs
    except Exception:
        return np.nan

def evaluate_model(model, data_loader, device, pkd_bounds):
    model.eval()
    all_labels, all_preds_pkd, all_pdb_groups, all_subgroups, all_sources = [], [], [], [], []
    pkd_lower, pkd_range = pkd_bounds[0], pkd_bounds[1] - pkd_bounds[0]
    all_ligands, all_receptors = [], [] 

    with torch.no_grad():
        for batch in data_loader:
            outputs = model(batch)
            cosine_sim = outputs['cosine_similarity'].cpu()
            preds_pkd = ((cosine_sim + 1) / 2) * pkd_range + pkd_lower

            all_labels.extend(batch['original_pkds'].numpy())
            all_preds_pkd.extend(preds_pkd.numpy())
            all_pdb_groups.extend(batch['pdb_groups'])
            all_subgroups.extend(batch['subgroups'])
            all_sources.extend(batch['source_dataset']) # NEW
            all_ligands.extend(batch['ligand_name'])     # NEW
            all_receptors.extend(batch['receptor_name']) # NEW

    labels, preds = np.array(all_labels), np.array(all_preds_pkd)

    mask = ~np.isnan(labels) & ~np.isnan(preds)
    labels_masked, preds_masked = labels[mask], preds[mask]

    if len(labels_masked) < 2:
        metrics = {"rmse": np.nan, "pearson": np.nan, "spearman": np.nan, "ci": np.nan}
    else:
        metrics = {
            'rmse': np.sqrt(mean_squared_error(labels_masked, preds_masked)),
            'pearson': pearsonr(labels_masked, preds_masked)[0],
            'spearman': spearmanr(labels_masked, preds_masked)[0],
            'ci': concordance_index(labels_masked, preds_masked)
        }
    return metrics, labels, preds, np.array(all_pdb_groups), np.array(all_subgroups), \
           np.array(all_sources), np.array(all_ligands), np.array(all_receptors)

def plot_regression(y_true, y_pred, metrics, title, filename=None):
    plt.figure(figsize=(8, 8))
    sns.scatterplot(x=y_true, y=y_pred, alpha=0.6, edgecolor='k', s=50)
    min_val, max_val = min(np.min(y_true), np.min(y_pred)), max(np.max(y_true), np.max(y_pred))
    plt.plot([min_val, max_val], [min_val, max_val], 'r--', lw=2, label='Identity Line (y=x)')
    metrics_text = f"RMSE: {metrics['rmse']:.4f}\nPearson: {metrics['pearson']:.4f}\nSpearman: {metrics['spearman']:.4f}\nCI: {metrics['ci']:.4f}"
    plt.text(0.05, 0.95, metrics_text, transform=plt.gca().transAxes, fontsize=12, verticalalignment='top', bbox=dict(boxstyle='round,pad=0.5', fc='yellow', alpha=0.5))
    plt.title(title, fontsize=16)
    plt.xlabel("Actual pKd", fontsize=14)
    plt.ylabel("Predicted pKd", fontsize=14)
    plt.legend()
    plt.grid(True)
    plt.tight_layout()
    if filename:
        plt.savefig(filename)
        print(f"Plot saved to {filename}")
    plt.show()

# ==============================================================================
# 7. CROSS-VALIDATION TRAINING
# ==============================================================================
print("\n" + "="*80)
print("... 7. RUNNING 'COLD TARGET' (GROUPKFOLD) STRATEGY WITH LoRA ...")

def get_groupkfold_splits(df: pd.DataFrame, n_splits: int):
    print(f"\n❄️ Preparing {n_splits}-Fold **GroupKFold (Cold Target)** splits...")
    gkf = GroupKFold(n_splits=n_splits)
    groups = df['PDB'].factorize()[0] # Factorize 'PDB' to get integer groups
    for fold, (train_idx, test_idx) in enumerate(gkf.split(df, groups=groups)):
        train_targets = set(df.iloc[train_idx]['PDB'].unique())
        test_targets = set(df.iloc[test_idx]['PDB'].unique())

        # Check for leakage at the group level
        if not train_targets.intersection(test_targets):
            print(f"  ✅ Fold {fold+1}: No 'PDB' group leakage detected. Train groups: {len(train_targets)}, Test groups: {len(test_targets)}")
        else:
            print(f"  ❌ Fold {fold+1} FAILED: PDB group leakage detected! Leaked groups: {train_targets.intersection(test_targets)}")

        # With n_splits=5, this gives an 80/20 train/test split.
        train_ratio = len(train_idx) / len(df)
        print(f"    Row split: Train {len(train_idx)} ({train_ratio:.1%}), Test {len(test_idx)} ({1-train_ratio:.1%})")

        yield train_idx, test_idx

def run_cold_target_cv_with_lora():
    if df.empty:
        print("⚠️ Skipping training due to empty dataframe.")
        return

    device = torch.device("cuda" if torch.cuda.is_available() else "cpu")
    PKD_LOWER_BOUND, PKD_UPPER_BOUND = df['Y'].min(), df['Y'].max()
    PKD_BOUNDS = (PKD_LOWER_BOUND, PKD_UPPER_BOUND)
    print(f"Global pKd bounds for scaling: [{PKD_LOWER_BOUND:.2f}, {PKD_UPPER_BOUND:.2f}]")

    print(f"\n🚀 Starting {N_SPLITS}-Fold **{CV_STRATEGY}** Cross-Validation with LoRA fine-tuning...")



    splits = get_groupkfold_splits(df, N_SPLITS)
    fold_results, all_folds_y_true, all_folds_y_pred = [], [], []

    for fold, (train_ids, val_ids) in enumerate(splits):
        fold_num = fold + 1
        print(f"\n===== STRATEGY: {CV_STRATEGY} | FOLD {fold_num}/{N_SPLITS} =====")

        train_df, val_df = df.iloc[train_ids], df.iloc[val_ids]
        train_dataset = ProteinPairSequenceDataset(train_df, PKD_BOUNDS)
        val_dataset = ProteinPairSequenceDataset(val_df, PKD_BOUNDS)
        train_loader = DataLoader(train_dataset, batch_size=BATCH_SIZE, shuffle=True, collate_fn=collate_fn_sequences)
        val_loader = DataLoader(val_dataset, batch_size=BATCH_SIZE*2, shuffle=False, collate_fn=collate_fn_sequences)

        # --- FIX 1: INITIALIZE FRESH MODEL INSIDE THE LOOP ---
        print(f"🏗️ Loading fresh ESM-2 and LoRA adapters for Fold {fold_num}...")
        extractor = ProteinEmbeddingExtractor(
            device=device,
            use_lora=USE_LORA_FOR_TRAINING,
            lora_rank=LORA_RANK,
            lora_alpha=LORA_ALPHA,
            lora_dropout=LORA_DROPOUT
        )
        base_esm_model, esm_tokenizer = extractor.get_model_and_tokenizer()

        model = BALMForLoRAFinetuning(
            esm_model=base_esm_model,
            esm_tokenizer=esm_tokenizer,
            projected_size=PROJECTED_SIZE,
            projected_dropout=DROPOUT,
            pkd_bounds=PKD_BOUNDS
        ).to(device)

        optimizer = AdamW(model.parameters(), lr=LEARNING_RATE)
        print(f"   Optimizing {sum(p.numel() for p in model.parameters() if p.requires_grad)} trainable parameters.")

        best_val_metric = float('inf')
        patience_counter = 0
        fold_model_path = os.path.join(RESULTS_DIR, f"best_model_fold_{fold_num}.pth")

        for epoch in range(EPOCHS):
            model.train()
            total_train_loss = 0.0
            progress_bar = tqdm(train_loader, desc=f"Epoch {epoch+1}/{EPOCHS} (Fold {fold_num})", leave=False)

            for batch in progress_bar:
                optimizer.zero_grad()
                batch_gpu = {k: v for k, v in batch.items()}
                for key in ["labels", "original_pkds"]:
                    if key in batch_gpu: batch_gpu[key] = batch_gpu[key].to(device)

                outputs = model(batch_gpu)
                loss = outputs['loss']
                loss.backward()
                optimizer.step()
                total_train_loss += loss.item()
                progress_bar.set_postfix({'batch_loss': f"{loss.item():.4f}"})

            avg_train_loss = total_train_loss / len(train_loader)

            val_metrics, _, _, _, _, _, _, _ = evaluate_model(model, val_loader, device, PKD_BOUNDS)

            current_val_metric = val_metrics['rmse']

            print(f"Epoch {epoch+1}/{EPOCHS} | Train Loss: {avg_train_loss:.4f} | Val RMSE: {current_val_metric:.4f} | Val Pearson: {val_metrics['pearson']:.4f}")

            if current_val_metric < best_val_metric:
                best_val_metric = current_val_metric
                patience_counter = 0
                torch.save(model.state_dict(), fold_model_path)
                print(f"   -> New best model for Fold {fold_num} saved with Val RMSE: {best_val_metric:.4f}")
            else:
                patience_counter += 1

            if patience_counter >= PATIENCE:
                print(f"⏳ Early stopping triggered at epoch {epoch+1} for Fold {fold_num}. Val RMSE has not improved for {PATIENCE} epochs.")
                break

        print(f"Fold {fold_num} training complete.")

        if os.path.exists(fold_model_path):
            print(f"Loading best model for Fold {fold_num} for final evaluation...")
            model.load_state_dict(torch.load(fold_model_path))
        else:
            print(f"WARNING: No best model found for Fold {fold_num}. Using last epoch's model.")

        metrics, y_t, y_p, pdbs, subgrps, srcs, ligands, receptors = evaluate_model(model, val_loader, device, PKD_BOUNDS)
        print(f"Fold {fold_num} Final Validation Metrics:")
        for key, value in metrics.items():
            print(f"  - {key.upper()}: {value:.4f}")

        fold_results.append(metrics)
        all_folds_y_true.extend(y_t)
        all_folds_y_pred.extend(y_p)

        # --- Save results to CSV for the current fold ---
        fold_output_df = pd.DataFrame({
            'Ligand Name': ligands,       # NEW
            'Receptor Name': receptors,   # NEW
            'label': y_t,
            'prediction': y_p,
            'residual': y_t - y_p,
            'PDB': pdbs,
            'Subgroup': subgrps,
            'Source': srcs
        })
        fold_output_filename = os.path.join(RESULTS_DIR, f"fold_{fold_num}_predictions.csv")
        fold_output_df.to_csv(fold_output_filename, index=False)
        print(f"Predictions for Fold {fold_num} saved to {fold_output_filename}")

        del model
        del base_esm_model
        del extractor
        import gc
        gc.collect()
        torch.cuda.empty_cache()

    print(f"\n📈 Generating combined regression plot for {CV_STRATEGY}")
    combined_y_true = np.array(all_folds_y_true)
    combined_y_pred = np.array(all_folds_y_pred)

    overall_metrics = {
        'rmse': np.sqrt(mean_squared_error(combined_y_true, combined_y_pred)),
        'pearson': pearsonr(combined_y_true, combined_y_pred)[0],
        'spearman': spearmanr(combined_y_true, combined_y_pred)[0],
        'ci': concordance_index(combined_y_true, combined_y_pred)
    }

    plot_regression(
        combined_y_true,
        combined_y_pred,
        overall_metrics,
        title=f"Overall Regression for {CV_STRATEGY} ({N_SPLITS}-Fold CV) with LoRA Fine-tuning",
        filename=os.path.join(RESULTS_DIR, "overall_regression_plot.png")
    )

    print(f"\n✅ Final Results Summary for {CV_STRATEGY} with LoRA Fine-tuning:")
    results_df = pd.DataFrame(fold_results)
    summary_df = pd.DataFrame({'Mean': results_df.mean(), 'Std Dev': results_df.std()})
    print(summary_df)

    summary_filename = os.path.join(RESULTS_DIR, "cv_summary_metrics.csv")
    summary_df.to_csv(summary_filename)
    print(f"Overall CV summary metrics saved to {summary_filename}")
    print(f"Fold model checkpoints and prediction files are saved in the '{RESULTS_DIR}' directory.")


# --- Call the CV function ---
run_cold_target_cv_with_lora()

# ==============================================================================
# 8. FINAL NOTES AND RECOMMENDATIONS
# ==============================================================================
print("\n" + "="*80)
print("... 8. FINAL NOTES AND RECOMMENDATIONS ...")
print("""
🎉 CONGRATULATIONS! You've successfully implemented BALM with on-the-fly ESM-2 embeddings
and **Parameter-Efficient Fine-Tuning (PEFT) using LoRA**!

📊 KEY ADVANTAGES OF THIS APPROACH:
• **Efficiency:** Fine-tunes only a tiny fraction of the ESM-2 model parameters (<1%).
• **Speed & Memory:** Significantly faster and less memory-intensive than full fine-tuning.
• **Performance:** Adapts the powerful ESM-2 model to your specific data, often leading to better performance.
• **No Static Cache:** By computing embeddings dynamically, the model fully leverages the fine-tuned LoRA adapters during training.

🚀 PERFORMANCE OPTIMIZATION TIPS:
1.  **LoRA Hyperparameters:**
    *   `lora_rank (r)`: Controls the capacity of the adapters. Higher `r` means more parameters. Typical values are 8-64.
    *   `lora_alpha`: Acts as a scaling factor. A common heuristic is to set `lora_alpha` to be twice the `lora_rank`.
    *   `target_modules`: Experiment with adding other modules like `dense` to the target list in the `LoraConfig`.
2.  **Learning Rate:** LoRA can sometimes handle slightly higher learning rates than full fine-tuning. Experiment with values from 5e-5 to 5e-4.
3.  **Batch Size & Gradient Accumulation:** If your GPU memory is a constraint, you can simulate a larger batch size by using gradient accumulation.

💾 SAVING AND LOADING THE FINE-TUNED MODEL:
• The script now saves the full state dictionary for each fold in the `cv_results_lora` directory.
• To save only the trained LoRA adapters (more efficient for storage):
    `model.esm_model.save_pretrained("path/to/my_lora_adapters")`
• To load: First, load the base ESM-2 model. Then, use `PeftModel.from_pretrained(base_model, "path/to/my_lora_adapters")`.

🎯 NEXT STEPS:
1.  **Hyperparameter Search:** Systematically tune LoRA parameters (`r`, `lora_alpha`) and the learning rate for optimal performance.
2.  **Experiment with Larger ESM-2 Models:** LoRA makes fine-tuning even the largest ESM-2 models (e.g., 3B parameters) feasible on a single high-end GPU.
3.  **Advanced PEFT Techniques:** Explore other PEFT methods like IA3 or full parameter-efficient fine-tuning for comparison.
""")
print("\n✅ LoRA PEFT implementation complete! Happy parameter-efficient protein modeling! 🧬🤖")
# Out:
# ================================================================================
# ... 0. PEFT LIBRARY INITIALIZED ...
#     Ready for Parameter-Efficient Fine-Tuning with LoRA!
# 🧬 BALM Adaptation for ESM-2 with LoRA Fine-Tuning
# ⚡ Fast Training with 5-Fold Cross-Validation
# ================================================================================
# 🔒 Setting up reproducibility with seed 42
# ✅ Reproducibility setup complete
# ✅ Data loaded. Final dataset size: 12019 samples.
#
# ================================================================================
# ... 4. CONFIGURING THE EXPERIMENT ...
# Results will be saved in: cv_results_lora
# ✅ Configuration set. Using CV Strategy: GroupKFold
#    Epochs: 30, Patience: 15
#    LoRA Enabled: Rank=8, Alpha=16, Dropout=0.1
#
# ================================================================================
# ... 5. DEFINING ADAPTED MODEL AND DATASET ...
#
# ================================================================================
# ... 6. DEFINING METRICS AND EVALUATION ...
#
# ================================================================================
# ... 7. RUNNING 'COLD TARGET' (GROUPKFOLD) STRATEGY WITH LoRA ...
# Global pKd bounds for scaling: [1.32, 15.70]
#
# 🚀 Starting 5-Fold **GroupKFold** Cross-Validation with LoRA fine-tuning...
#
# ❄️ Preparing 5-Fold **GroupKFold (Cold Target)** splits...
#   ✅ Fold 1: No 'PDB' group leakage detected. Train groups: 2421, Test groups: 606
#     Row split: Train 9615 (80.0%), Test 2404 (20.0%)
#
# ===== STRATEGY: GroupKFold | FOLD 1/5 =====
# 🏗️ Loading fresh ESM-2 and LoRA adapters for Fold 1...
# 🔧 Initializing ProteinEmbeddingExtractor on cuda
# 📥 Loading ESM-2 model: facebook/esm2_t33_650M_UR50D with dtype: torch.float16
# Some weights of EsmModel were not initialized from the model checkpoint at facebook/esm2_t33_650M_UR50D and are newly initialized: ['esm.pooler.dense.bias', 'esm.pooler.dense.weight']
# You should probably TRAIN this model on a down-stream task to be able to use it for predictions and inference.
# ✨ Applying LoRA with rank=8, alpha=16, dropout=0.1
#    ✅ LoRA model loaded and configured. Trainable parameters:
# trainable params: 2,027,520 || all params: 654,381,461 || trainable%: 0.3098
#    ✅ Model loaded. Embedding size from config: 1280
# ✅ BALMProjectionHead initialized with embedding_size: 1280
# ✅ BALM model initialized using CLS token: <cls>
#    Optimizing 2683392 trainable parameters.
# Epoch 1/30 | Train Loss: 0.0426 | Val RMSE: 1.6254 | Val Pearson: 0.6468
#    -> New best model for Fold 1 saved with Val RMSE: 1.6254
# Epoch 2/30 | Train Loss: 0.0302 | Val RMSE: 1.5578 | Val Pearson: 0.6931
#    -> New best model for Fold 1 saved with Val RMSE: 1.5578
# Epoch 3/30 | Train Loss: 0.0250 | Val RMSE: 1.6297 | Val Pearson: 0.6356
# Epoch 4/30 | Train Loss: 0.0216 | Val RMSE: 1.5314 | Val Pearson: 0.6904
#    -> New best model for Fold 1 saved with Val RMSE: 1.5314
# Epoch 5/30 | Train Loss: 0.0194 | Val RMSE: 1.4702 | Val Pearson: 0.7208
#    -> New best model for Fold 1 saved with Val RMSE: 1.4702
# Epoch 6/30 | Train Loss: 0.0174 | Val RMSE: 1.4439 | Val Pearson: 0.7360
#    -> New best model for Fold 1 saved with Val RMSE: 1.4439
# Epoch 7/30 | Train Loss: 0.0159 | Val RMSE: 1.5078 | Val Pearson: 0.7480
# Epoch 8/30 | Train Loss: 0.0148 | Val RMSE: 1.4709 | Val Pearson: 0.7224
# Epoch 9/30 | Train Loss: 0.0139 | Val RMSE: 1.4084 | Val Pearson: 0.7476
#    -> New best model for Fold 1 saved with Val RMSE: 1.4084
# Epoch 10/30 | Train Loss: 0.0132 | Val RMSE: 1.4097 | Val Pearson: 0.7456
# Epoch 11/30 | Train Loss: 0.0127 | Val RMSE: 1.4671 | Val Pearson: 0.7194
# Epoch 12/30 | Train Loss: 0.0124 | Val RMSE: 1.4243 | Val Pearson: 0.7375
# Epoch 13/30 | Train Loss: 0.0117 | Val RMSE: 1.4470 | Val Pearson: 0.7485
# Epoch 14/30 | Train Loss: 0.0112 | Val RMSE: 1.4297 | Val Pearson: 0.7390
# Epoch 15/30 | Train Loss: 0.0107 | Val RMSE: 1.3654 | Val Pearson: 0.7643
#    -> New best model for Fold 1 saved with Val RMSE: 1.3654
# Epoch 16/30 | Train Loss: 0.0106 | Val RMSE: 1.3933 | Val Pearson: 0.7498
# Epoch 17/30 | Train Loss: 0.0102 | Val RMSE: 1.3980 | Val Pearson: 0.7492
# Epoch 18/30 | Train Loss: 0.0099 | Val RMSE: 1.3876 | Val Pearson: 0.7538
# Epoch 19/30 | Train Loss: 0.0096 | Val RMSE: 1.4398 | Val Pearson: 0.7317
# Epoch 20/30 | Train Loss: 0.0097 | Val RMSE: 1.4220 | Val Pearson: 0.7406
# Epoch 21/30 | Train Loss: 0.0093 | Val RMSE: 1.4118 | Val Pearson: 0.7480
# Epoch 22/30 | Train Loss: 0.0090 | Val RMSE: 1.4003 | Val Pearson: 0.7556
# Epoch 23/30 | Train Loss: 0.0088 | Val RMSE: 1.4127 | Val Pearson: 0.7597
# Epoch 24/30 | Train Loss: 0.0089 | Val RMSE: 1.3632 | Val Pearson: 0.7651
#    -> New best model for Fold 1 saved with Val RMSE: 1.3632
# Epoch 25/30 | Train Loss: 0.0086 | Val RMSE: 1.3961 | Val Pearson: 0.7531
# Epoch 26/30 | Train Loss: 0.0085 | Val RMSE: 1.3755 | Val Pearson: 0.7679
# Epoch 27/30 | Train Loss: 0.0083 | Val RMSE: 1.4167 | Val Pearson: 0.7540
# Epoch 28/30 | Train Loss: 0.0081 | Val RMSE: 1.4292 | Val Pearson: 0.7451
# Epoch 29/30 | Train Loss: 0.0080 | Val RMSE: 1.4571 | Val Pearson: 0.7240
# Epoch 30/30 | Train Loss: 0.0080 | Val RMSE: 1.4458 | Val Pearson: 0.7446
# Fold 1 training complete.
# Loading best model for Fold 1 for final evaluation...
# C:\Users\hs494\AppData\Local\Temp\ipykernel_37948\1210814534.py:546: FutureWarning: You are using `torch.load` with `weights_only=False` (the current default value), which uses the default pickle module implicitly. It is possible to construct malicious pickle data which will execute arbitrary code during unpickling (See https://github.com/pytorch/pytorch/blob/main/SECURITY.md#untrusted-models for more details). In a future release, the default value for `weights_only` will be flipped to `True`. This limits the functions that could be executed during unpickling. Arbitrary objects will no longer be allowed to be loaded via this mode unless they are explicitly allowlisted by the user via `torch.serialization.add_safe_globals`. We recommend you start setting `weights_only=True` for any use case where you don't have full control of the loaded file. Please open an issue on GitHub for any issues related to this experimental feature.
#   model.load_state_dict(torch.load(fold_model_path))
# Fold 1 Final Validation Metrics:
#   - RMSE: 1.3632
#   - PEARSON: 0.7651
#   - SPEARMAN: 0.7727
#   - CI: 0.7865
# Predictions for Fold 1 saved to cv_results_lora\fold_1_predictions.csv
#   ✅ Fold 2: No 'PDB' group leakage detected. Train groups: 2422, Test groups: 605
#     Row split: Train 9615 (80.0%), Test 2404 (20.0%)
#
# ===== STRATEGY: GroupKFold | FOLD 2/5 =====
# 🏗️ Loading fresh ESM-2 and LoRA adapters for Fold 2...
# 🔧 Initializing ProteinEmbeddingExtractor on cuda
# 📥 Loading ESM-2 model: facebook/esm2_t33_650M_UR50D with dtype: torch.float16
# Some weights of EsmModel were not initialized from the model checkpoint at facebook/esm2_t33_650M_UR50D and are newly initialized: ['esm.pooler.dense.bias', 'esm.pooler.dense.weight']
# You should probably TRAIN this model on a down-stream task to be able to use it for predictions and inference.
# ✨ Applying LoRA with rank=8, alpha=16, dropout=0.1
#    ✅ LoRA model loaded and configured. Trainable parameters:
# trainable params: 2,027,520 || all params: 654,381,461 || trainable%: 0.3098
#    ✅ Model loaded. Embedding size from config: 1280
# ✅ BALMProjectionHead initialized with embedding_size: 1280
# ✅ BALM model initialized using CLS token: <cls>
#    Optimizing 2683392 trainable parameters.
# Epoch 1/30 | Train Loss: 0.0424 | Val RMSE: 1.6781 | Val Pearson: 0.6917
#    -> New best model for Fold 2 saved with Val RMSE: 1.6781
# Epoch 2/30 | Train Loss: 0.0304 | Val RMSE: 1.6152 | Val Pearson: 0.6981
#    -> New best model for Fold 2 saved with Val RMSE: 1.6152
# Epoch 3/30 | Train Loss: 0.0252 | Val RMSE: 1.6400 | Val Pearson: 0.7081
# Epoch 4/30 | Train Loss: 0.0214 | Val RMSE: 1.6144 | Val Pearson: 0.6994
#    -> New best model for Fold 2 saved with Val RMSE: 1.6144
# Epoch 5/30 | Train Loss: 0.0189 | Val RMSE: 1.6300 | Val Pearson: 0.6883
# Epoch 6/30 | Train Loss: 0.0170 | Val RMSE: 1.6428 | Val Pearson: 0.6943
# Epoch 7/30 | Train Loss: 0.0160 | Val RMSE: 1.6675 | Val Pearson: 0.7083
# Epoch 8/30 | Train Loss: 0.0151 | Val RMSE: 1.6618 | Val Pearson: 0.6975
# Epoch 9/30 | Train Loss: 0.0143 | Val RMSE: 1.6246 | Val Pearson: 0.6866
# Epoch 10/30 | Train Loss: 0.0134 | Val RMSE: 1.7064 | Val Pearson: 0.6584
# Epoch 11/30 | Train Loss: 0.0131 | Val RMSE: 1.6317 | Val Pearson: 0.6992
# Epoch 12/30 | Train Loss: 0.0124 | Val RMSE: 1.6391 | Val Pearson: 0.6833
# Epoch 13/30 | Train Loss: 0.0117 | Val RMSE: 1.6679 | Val Pearson: 0.6948
# Epoch 14/30 | Train Loss: 0.0114 | Val RMSE: 1.6499 | Val Pearson: 0.6945
# Epoch 15/30 | Train Loss: 0.0110 | Val RMSE: 1.6245 | Val Pearson: 0.7058
# Epoch 16/30 | Train Loss: 0.0107 | Val RMSE: 1.6505 | Val Pearson: 0.6945
# Epoch 17/30 | Train Loss: 0.0102 | Val RMSE: 1.6342 | Val Pearson: 0.6917
# Epoch 18/30 | Train Loss: 0.0097 | Val RMSE: 1.6768 | Val Pearson: 0.6716
# Epoch 19/30 | Train Loss: 0.0097 | Val RMSE: 1.6530 | Val Pearson: 0.7012
# ⏳ Early stopping triggered at epoch 19 for Fold 2. Val RMSE has not improved for 15 epochs.
# Fold 2 training complete.
# Loading best model for Fold 2 for final evaluation...
# C:\Users\hs494\AppData\Local\Temp\ipykernel_37948\1210814534.py:546: FutureWarning: You are using `torch.load` with `weights_only=False` (the current default value), which uses the default pickle module implicitly. It is possible to construct malicious pickle data which will execute arbitrary code during unpickling (See https://github.com/pytorch/pytorch/blob/main/SECURITY.md#untrusted-models for more details). In a future release, the default value for `weights_only` will be flipped to `True`. This limits the functions that could be executed during unpickling. Arbitrary objects will no longer be allowed to be loaded via this mode unless they are explicitly allowlisted by the user via `torch.serialization.add_safe_globals`. We recommend you start setting `weights_only=True` for any use case where you don't have full control of the loaded file. Please open an issue on GitHub for any issues related to this experimental feature.
#   model.load_state_dict(torch.load(fold_model_path))
# Fold 2 Final Validation Metrics:
#   - RMSE: 1.6144
#   - PEARSON: 0.6994
#   - SPEARMAN: 0.6772
#   - CI: 0.7488
# Predictions for Fold 2 saved to cv_results_lora\fold_2_predictions.csv
#   ✅ Fold 3: No 'PDB' group leakage detected. Train groups: 2422, Test groups: 605
#     Row split: Train 9615 (80.0%), Test 2404 (20.0%)
#
# ===== STRATEGY: GroupKFold | FOLD 3/5 =====
# 🏗️ Loading fresh ESM-2 and LoRA adapters for Fold 3...
# 🔧 Initializing ProteinEmbeddingExtractor on cuda
# 📥 Loading ESM-2 model: facebook/esm2_t33_650M_UR50D with dtype: torch.float16
# Some weights of EsmModel were not initialized from the model checkpoint at facebook/esm2_t33_650M_UR50D and are newly initialized: ['esm.pooler.dense.bias', 'esm.pooler.dense.weight']
# You should probably TRAIN this model on a down-stream task to be able to use it for predictions and inference.
# ✨ Applying LoRA with rank=8, alpha=16, dropout=0.1
#    ✅ LoRA model loaded and configured. Trainable parameters:
# trainable params: 2,027,520 || all params: 654,381,461 || trainable%: 0.3098
#    ✅ Model loaded. Embedding size from config: 1280
# ✅ BALMProjectionHead initialized with embedding_size: 1280
# ✅ BALM model initialized using CLS token: <cls>
#    Optimizing 2683392 trainable parameters.
# Epoch 1/30 | Train Loss: 0.0420 | Val RMSE: 1.6741 | Val Pearson: 0.6725
#    -> New best model for Fold 3 saved with Val RMSE: 1.6741
# Epoch 2/30 | Train Loss: 0.0308 | Val RMSE: 1.6927 | Val Pearson: 0.6649
# Epoch 3/30 | Train Loss: 0.0251 | Val RMSE: 1.7732 | Val Pearson: 0.6647
# Epoch 4/30 | Train Loss: 0.0219 | Val RMSE: 1.8355 | Val Pearson: 0.6381
# Epoch 5/30 | Train Loss: 0.0193 | Val RMSE: 1.7734 | Val Pearson: 0.6355
# Epoch 6/30 | Train Loss: 0.0181 | Val RMSE: 1.6208 | Val Pearson: 0.6879
#    -> New best model for Fold 3 saved with Val RMSE: 1.6208
# Epoch 7/30 | Train Loss: 0.0167 | Val RMSE: 1.6813 | Val Pearson: 0.6826
# Epoch 8/30 | Train Loss: 0.0153 | Val RMSE: 1.6261 | Val Pearson: 0.6929
# Epoch 9/30 | Train Loss: 0.0146 | Val RMSE: 1.6197 | Val Pearson: 0.7035
#    -> New best model for Fold 3 saved with Val RMSE: 1.6197
# Epoch 10/30 | Train Loss: 0.0139 | Val RMSE: 1.6809 | Val Pearson: 0.6889
# Epoch 11/30 | Train Loss: 0.0135 | Val RMSE: 1.6448 | Val Pearson: 0.7072
# Epoch 12/30 | Train Loss: 0.0132 | Val RMSE: 1.6066 | Val Pearson: 0.6941
#    -> New best model for Fold 3 saved with Val RMSE: 1.6066
# Epoch 13/30 | Train Loss: 0.0125 | Val RMSE: 1.6162 | Val Pearson: 0.6951
# Epoch 14/30 | Train Loss: 0.0118 | Val RMSE: 1.6561 | Val Pearson: 0.7026
# Epoch 15/30 | Train Loss: 0.0115 | Val RMSE: 1.6048 | Val Pearson: 0.6987
#    -> New best model for Fold 3 saved with Val RMSE: 1.6048
# Epoch 16/30 | Train Loss: 0.0110 | Val RMSE: 1.6054 | Val Pearson: 0.7128
# Epoch 17/30 | Train Loss: 0.0106 | Val RMSE: 1.7615 | Val Pearson: 0.7023
# Epoch 18/30 | Train Loss: 0.0102 | Val RMSE: 1.6463 | Val Pearson: 0.7013
# Epoch 19/30 | Train Loss: 0.0100 | Val RMSE: 1.5753 | Val Pearson: 0.7140
#    -> New best model for Fold 3 saved with Val RMSE: 1.5753
# Epoch 20/30 | Train Loss: 0.0098 | Val RMSE: 1.6981 | Val Pearson: 0.6950
# Epoch 21/30 | Train Loss: 0.0097 | Val RMSE: 1.6801 | Val Pearson: 0.6908
# Epoch 22/30 | Train Loss: 0.0094 | Val RMSE: 1.6315 | Val Pearson: 0.6984
# Epoch 23/30 | Train Loss: 0.0091 | Val RMSE: 1.6894 | Val Pearson: 0.7054
# Epoch 24/30 | Train Loss: 0.0089 | Val RMSE: 1.6041 | Val Pearson: 0.7145
# Epoch 25/30 | Train Loss: 0.0087 | Val RMSE: 1.6006 | Val Pearson: 0.7142
# Epoch 26/30 | Train Loss: 0.0086 | Val RMSE: 1.6166 | Val Pearson: 0.7195
# Epoch 27/30 | Train Loss: 0.0086 | Val RMSE: 1.5902 | Val Pearson: 0.7091
# Epoch 28/30 | Train Loss: 0.0083 | Val RMSE: 1.6070 | Val Pearson: 0.7124
# Epoch 29/30 | Train Loss: 0.0081 | Val RMSE: 1.6298 | Val Pearson: 0.7093
# Epoch 30/30 | Train Loss: 0.0079 | Val RMSE: 1.5908 | Val Pearson: 0.7178
# Fold 3 training complete.
# Loading best model for Fold 3 for final evaluation...
# C:\Users\hs494\AppData\Local\Temp\ipykernel_37948\1210814534.py:546: FutureWarning: You are using `torch.load` with `weights_only=False` (the current default value), which uses the default pickle module implicitly. It is possible to construct malicious pickle data which will execute arbitrary code during unpickling (See https://github.com/pytorch/pytorch/blob/main/SECURITY.md#untrusted-models for more details). In a future release, the default value for `weights_only` will be flipped to `True`. This limits the functions that could be executed during unpickling. Arbitrary objects will no longer be allowed to be loaded via this mode unless they are explicitly allowlisted by the user via `torch.serialization.add_safe_globals`. We recommend you start setting `weights_only=True` for any use case where you don't have full control of the loaded file. Please open an issue on GitHub for any issues related to this experimental feature.
#   model.load_state_dict(torch.load(fold_model_path))
# Fold 3 Final Validation Metrics:
#   - RMSE: 1.5753
#   - PEARSON: 0.7140
#   - SPEARMAN: 0.6630
#   - CI: 0.7385
# Predictions for Fold 3 saved to cv_results_lora\fold_3_predictions.csv
#   ✅ Fold 4: No 'PDB' group leakage detected. Train groups: 2421, Test groups: 606
#     Row split: Train 9615 (80.0%), Test 2404 (20.0%)
#
# ===== STRATEGY: GroupKFold | FOLD 4/5 =====
# 🏗️ Loading fresh ESM-2 and LoRA adapters for Fold 4...
# 🔧 Initializing ProteinEmbeddingExtractor on cuda
# 📥 Loading ESM-2 model: facebook/esm2_t33_650M_UR50D with dtype: torch.float16
# Some weights of EsmModel were not initialized from the model checkpoint at facebook/esm2_t33_650M_UR50D and are newly initialized: ['esm.pooler.dense.bias', 'esm.pooler.dense.weight']
# You should probably TRAIN this model on a down-stream task to be able to use it for predictions and inference.
# ✨ Applying LoRA with rank=8, alpha=16, dropout=0.1
#    ✅ LoRA model loaded and configured. Trainable parameters:
# trainable params: 2,027,520 || all params: 654,381,461 || trainable%: 0.3098
#    ✅ Model loaded. Embedding size from config: 1280
# ✅ BALMProjectionHead initialized with embedding_size: 1280
# ✅ BALM model initialized using CLS token: <cls>
#    Optimizing 2683392 trainable parameters.
# Epoch 1/30 | Train Loss: 0.0431 | Val RMSE: 1.5359 | Val Pearson: 0.6983
#    -> New best model for Fold 4 saved with Val RMSE: 1.5359
# Epoch 2/30 | Train Loss: 0.0308 | Val RMSE: 1.4342 | Val Pearson: 0.7007
#    -> New best model for Fold 4 saved with Val RMSE: 1.4342
# Epoch 3/30 | Train Loss: 0.0252 | Val RMSE: 1.4427 | Val Pearson: 0.7152
# Epoch 4/30 | Train Loss: 0.0217 | Val RMSE: 1.4261 | Val Pearson: 0.7232
#    -> New best model for Fold 4 saved with Val RMSE: 1.4261
# Epoch 5/30 | Train Loss: 0.0187 | Val RMSE: 1.4877 | Val Pearson: 0.7096
# Epoch 6/30 | Train Loss: 0.0174 | Val RMSE: 1.4515 | Val Pearson: 0.7101
# Epoch 7/30 | Train Loss: 0.0157 | Val RMSE: 1.4426 | Val Pearson: 0.7079
# Epoch 8/30 | Train Loss: 0.0147 | Val RMSE: 1.4437 | Val Pearson: 0.7149
# Epoch 9/30 | Train Loss: 0.0139 | Val RMSE: 1.4458 | Val Pearson: 0.7098
# Epoch 10/30 | Train Loss: 0.0131 | Val RMSE: 1.4191 | Val Pearson: 0.7266
#    -> New best model for Fold 4 saved with Val RMSE: 1.4191
# Epoch 11/30 | Train Loss: 0.0125 | Val RMSE: 1.4329 | Val Pearson: 0.7152
# Epoch 12/30 | Train Loss: 0.0119 | Val RMSE: 1.4347 | Val Pearson: 0.7174
# Epoch 13/30 | Train Loss: 0.0118 | Val RMSE: 1.4224 | Val Pearson: 0.7287
# Epoch 14/30 | Train Loss: 0.0111 | Val RMSE: 1.4339 | Val Pearson: 0.7181
# Epoch 15/30 | Train Loss: 0.0106 | Val RMSE: 1.4338 | Val Pearson: 0.7158
# Epoch 16/30 | Train Loss: 0.0103 | Val RMSE: 1.4264 | Val Pearson: 0.7213
# Epoch 17/30 | Train Loss: 0.0100 | Val RMSE: 1.3712 | Val Pearson: 0.7380
#    -> New best model for Fold 4 saved with Val RMSE: 1.3712
# Epoch 18/30 | Train Loss: 0.0096 | Val RMSE: 1.4375 | Val Pearson: 0.7279
# Epoch 19/30 | Train Loss: 0.0092 | Val RMSE: 1.4347 | Val Pearson: 0.7209
# Epoch 20/30 | Train Loss: 0.0091 | Val RMSE: 1.4390 | Val Pearson: 0.7231
# Epoch 21/30 | Train Loss: 0.0088 | Val RMSE: 1.4317 | Val Pearson: 0.7275
# Epoch 22/30 | Train Loss: 0.0086 | Val RMSE: 1.4324 | Val Pearson: 0.7192
# Epoch 23/30 | Train Loss: 0.0086 | Val RMSE: 1.4232 | Val Pearson: 0.7258
# Epoch 24/30 | Train Loss: 0.0081 | Val RMSE: 1.4971 | Val Pearson: 0.7143
# Epoch 25/30 | Train Loss: 0.0080 | Val RMSE: 1.4431 | Val Pearson: 0.7209
# Epoch 26/30 | Train Loss: 0.0078 | Val RMSE: 1.4339 | Val Pearson: 0.7346
# Epoch 27/30 | Train Loss: 0.0077 | Val RMSE: 1.4516 | Val Pearson: 0.7288
# Epoch 28/30 | Train Loss: 0.0076 | Val RMSE: 1.4551 | Val Pearson: 0.7267
# Epoch 29/30 | Train Loss: 0.0075 | Val RMSE: 1.4388 | Val Pearson: 0.7273
# Epoch 30/30 | Train Loss: 0.0072 | Val RMSE: 1.4336 | Val Pearson: 0.7281
# Fold 4 training complete.
# Loading best model for Fold 4 for final evaluation...
# C:\Users\hs494\AppData\Local\Temp\ipykernel_37948\1210814534.py:546: FutureWarning: You are using `torch.load` with `weights_only=False` (the current default value), which uses the default pickle module implicitly. It is possible to construct malicious pickle data which will execute arbitrary code during unpickling (See https://github.com/pytorch/pytorch/blob/main/SECURITY.md#untrusted-models for more details). In a future release, the default value for `weights_only` will be flipped to `True`. This limits the functions that could be executed during unpickling. Arbitrary objects will no longer be allowed to be loaded via this mode unless they are explicitly allowlisted by the user via `torch.serialization.add_safe_globals`. We recommend you start setting `weights_only=True` for any use case where you don't have full control of the loaded file. Please open an issue on GitHub for any issues related to this experimental feature.
#   model.load_state_dict(torch.load(fold_model_path))
# Fold 4 Final Validation Metrics:
#   - RMSE: 1.3712
#   - PEARSON: 0.7380
#   - SPEARMAN: 0.7457
#   - CI: 0.7785
# Predictions for Fold 4 saved to cv_results_lora\fold_4_predictions.csv
#   ✅ Fold 5: No 'PDB' group leakage detected. Train groups: 2422, Test groups: 605
#     Row split: Train 9616 (80.0%), Test 2403 (20.0%)
#
# ===== STRATEGY: GroupKFold | FOLD 5/5 =====
# 🏗️ Loading fresh ESM-2 and LoRA adapters for Fold 5...
# 🔧 Initializing ProteinEmbeddingExtractor on cuda
# 📥 Loading ESM-2 model: facebook/esm2_t33_650M_UR50D with dtype: torch.float16
# Some weights of EsmModel were not initialized from the model checkpoint at facebook/esm2_t33_650M_UR50D and are newly initialized: ['esm.pooler.dense.bias', 'esm.pooler.dense.weight']
# You should probably TRAIN this model on a down-stream task to be able to use it for predictions and inference.
# ✨ Applying LoRA with rank=8, alpha=16, dropout=0.1
#    ✅ LoRA model loaded and configured. Trainable parameters:
# trainable params: 2,027,520 || all params: 654,381,461 || trainable%: 0.3098
#    ✅ Model loaded. Embedding size from config: 1280
# ✅ BALMProjectionHead initialized with embedding_size: 1280
# ✅ BALM model initialized using CLS token: <cls>
#    Optimizing 2683392 trainable parameters.
# Epoch 1/30 | Train Loss: 0.0410 | Val RMSE: 1.6469 | Val Pearson: 0.6596
#    -> New best model for Fold 5 saved with Val RMSE: 1.6469
# Epoch 2/30 | Train Loss: 0.0285 | Val RMSE: 1.5874 | Val Pearson: 0.6931
#    -> New best model for Fold 5 saved with Val RMSE: 1.5874
# Epoch 3/30 | Train Loss: 0.0229 | Val RMSE: 1.6198 | Val Pearson: 0.7105
# Epoch 4/30 | Train Loss: 0.0194 | Val RMSE: 1.5839 | Val Pearson: 0.7171
#    -> New best model for Fold 5 saved with Val RMSE: 1.5839
# Epoch 5/30 | Train Loss: 0.0172 | Val RMSE: 1.6231 | Val Pearson: 0.6997
# Epoch 6/30 | Train Loss: 0.0158 | Val RMSE: 1.6062 | Val Pearson: 0.6997
# Epoch 7/30 | Train Loss: 0.0150 | Val RMSE: 1.5745 | Val Pearson: 0.7213
#    -> New best model for Fold 5 saved with Val RMSE: 1.5745
# Epoch 8/30 | Train Loss: 0.0142 | Val RMSE: 1.6317 | Val Pearson: 0.7167
# Epoch 9/30 | Train Loss: 0.0132 | Val RMSE: 1.5486 | Val Pearson: 0.7216
#    -> New best model for Fold 5 saved with Val RMSE: 1.5486
# Epoch 10/30 | Train Loss: 0.0125 | Val RMSE: 1.5631 | Val Pearson: 0.7300
# Epoch 11/30 | Train Loss: 0.0117 | Val RMSE: 1.5805 | Val Pearson: 0.7247
# Epoch 12/30 | Train Loss: 0.0115 | Val RMSE: 1.6097 | Val Pearson: 0.7079
# Epoch 13/30 | Train Loss: 0.0109 | Val RMSE: 1.5981 | Val Pearson: 0.7076
# Epoch 14/30 | Train Loss: 0.0107 | Val RMSE: 1.5825 | Val Pearson: 0.7274
# Epoch 15/30 | Train Loss: 0.0104 | Val RMSE: 1.5344 | Val Pearson: 0.7314
#    -> New best model for Fold 5 saved with Val RMSE: 1.5344
# Epoch 16/30 | Train Loss: 0.0098 | Val RMSE: 1.5607 | Val Pearson: 0.7131
# Epoch 17/30 | Train Loss: 0.0097 | Val RMSE: 1.5728 | Val Pearson: 0.7287
# Epoch 18/30 | Train Loss: 0.0094 | Val RMSE: 1.5147 | Val Pearson: 0.7303
#    -> New best model for Fold 5 saved with Val RMSE: 1.5147
# Epoch 19/30 | Train Loss: 0.0091 | Val RMSE: 1.5351 | Val Pearson: 0.7235
# Epoch 20/30 | Train Loss: 0.0089 | Val RMSE: 1.5190 | Val Pearson: 0.7255
# Epoch 21/30 | Train Loss: 0.0086 | Val RMSE: 1.5472 | Val Pearson: 0.7259
# Epoch 22/30 | Train Loss: 0.0085 | Val RMSE: 1.5353 | Val Pearson: 0.7231
# Epoch 23/30 | Train Loss: 0.0084 | Val RMSE: 1.5083 | Val Pearson: 0.7352
#    -> New best model for Fold 5 saved with Val RMSE: 1.5083
# Epoch 24/30 | Train Loss: 0.0082 | Val RMSE: 1.5869 | Val Pearson: 0.7224
# Epoch 25/30 | Train Loss: 0.0078 | Val RMSE: 1.5256 | Val Pearson: 0.7301
# Epoch 26/30 | Train Loss: 0.0077 | Val RMSE: 1.5865 | Val Pearson: 0.7295
# Epoch 27/30 | Train Loss: 0.0077 | Val RMSE: 1.5289 | Val Pearson: 0.7268
# Epoch 28/30 | Train Loss: 0.0075 | Val RMSE: 1.5569 | Val Pearson: 0.7257
# Epoch 29/30 | Train Loss: 0.0073 | Val RMSE: 1.5242 | Val Pearson: 0.7341
# Epoch 30/30 | Train Loss: 0.0072 | Val RMSE: 1.5426 | Val Pearson: 0.7352
# Fold 5 training complete.
# Loading best model for Fold 5 for final evaluation...
# C:\Users\hs494\AppData\Local\Temp\ipykernel_37948\1210814534.py:546: FutureWarning: You are using `torch.load` with `weights_only=False` (the current default value), which uses the default pickle module implicitly. It is possible to construct malicious pickle data which will execute arbitrary code during unpickling (See https://github.com/pytorch/pytorch/blob/main/SECURITY.md#untrusted-models for more details). In a future release, the default value for `weights_only` will be flipped to `True`. This limits the functions that could be executed during unpickling. Arbitrary objects will no longer be allowed to be loaded via this mode unless they are explicitly allowlisted by the user via `torch.serialization.add_safe_globals`. We recommend you start setting `weights_only=True` for any use case where you don't have full control of the loaded file. Please open an issue on GitHub for any issues related to this experimental feature.
#   model.load_state_dict(torch.load(fold_model_path))
# Fold 5 Final Validation Metrics:
#   - RMSE: 1.5083
#   - PEARSON: 0.7352
#   - SPEARMAN: 0.7168
#   - CI: 0.7638
# Predictions for Fold 5 saved to cv_results_lora\fold_5_predictions.csv
#
# 📈 Generating combined regression plot for GroupKFold
# Plot saved to cv_results_lora\overall_regression_plot.png
# ✅ Final Results Summary for GroupKFold with LoRA Fine-tuning:
#               Mean   Std Dev
# rmse      1.486473  0.115330
# pearson   0.730322  0.025082
# spearman  0.715096  0.045851
# ci        0.763238  0.019984
# Overall CV summary metrics saved to cv_results_lora\cv_summary_metrics.csv
# Fold model checkpoints and prediction files are saved in the 'cv_results_lora' directory.
#
# ================================================================================
# ... 8. FINAL NOTES AND RECOMMENDATIONS ...
#
# 🎉 CONGRATULATIONS! You've successfully implemented BALM with on-the-fly ESM-2 embeddings
# and **Parameter-Efficient Fine-Tuning (PEFT) using LoRA**!
#
# 📊 KEY ADVANTAGES OF THIS APPROACH:
# • **Efficiency:** Fine-tunes only a tiny fraction of the ESM-2 model parameters (<1%).
# • **Speed & Memory:** Significantly faster and less memory-intensive than full fine-tuning.
# • **Performance:** Adapts the powerful ESM-2 model to your specific data, often leading to better performance.
# • **No Static Cache:** By computing embeddings dynamically, the model fully leverages the fine-tuned LoRA adapters during training.
#
# 🚀 PERFORMANCE OPTIMIZATION TIPS:
# 1.  **LoRA Hyperparameters:**
#     *   `lora_rank (r)`: Controls the capacity of the adapters. Higher `r` means more parameters. Typical values are 8-64.
#     *   `lora_alpha`: Acts as a scaling factor. A common heuristic is to set `lora_alpha` to be twice the `lora_rank`.
#     *   `target_modules`: Experiment with adding other modules like `dense` to the target list in the `LoraConfig`.
# 2.  **Learning Rate:** LoRA can sometimes handle slightly higher learning rates than full fine-tuning. Experiment with values from 5e-5 to 5e-4.
# 3.  **Batch Size & Gradient Accumulation:** If your GPU memory is a constraint, you can simulate a larger batch size by using gradient accumulation.
#
# 💾 SAVING AND LOADING THE FINE-TUNED MODEL:
# • The script now saves the full state dictionary for each fold in the `cv_results_lora` directory.
# • To save only the trained LoRA adapters (more efficient for storage):
#     `model.esm_model.save_pretrained("path/to/my_lora_adapters")`
# • To load: First, load the base ESM-2 model. Then, use `PeftModel.from_pretrained(base_model, "path/to/my_lora_adapters")`.
#
# 🎯 NEXT STEPS:
# 1.  **Hyperparameter Search:** Systematically tune LoRA parameters (`r`, `lora_alpha`) and the learning rate for optimal performance.
# 2.  **Experiment with Larger ESM-2 Models:** LoRA makes fine-tuning even the largest ESM-2 models (e.g., 3B parameters) feasible on a single high-end GPU.
# 3.  **Advanced PEFT Techniques:** Explore other PEFT methods like IA3 or full parameter-efficient fine-tuning for comparison.
#
#
# ✅ LoRA PEFT implementation complete! Happy parameter-efficient protein modeling! 🧬🤖
